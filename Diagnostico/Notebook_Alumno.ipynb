# %% [markdown]
# # Diagnóstico
#
# Completa las celdas donde aparece ???
# Proyecto de análisis de datos con Python queremos hacer una regresion lineal

# %%
import pandas as pd
# importa librerías necesarias
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 # importa librerías necesarias
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv('???')
df.head()

# %% [markdown]
# ## Preprocesado

# %%
# convierte la columna zona a numérica
# ???

# %%
X = ???
y = ???

# %%
# divide train y test

# %%
# entrena modelo

# %% [markdown]
# ## Conclusiones
# Escribe 3 conclusiones sobre el modelo:
